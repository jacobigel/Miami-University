# %% [markdown]
# # Homework 6
# ## <u>Author:</u> Jacob Igel
# ### *ISA 414 - A*
#
# ***

# %% [markdown]
# # Preliminaries

# %%
import pandas as pd
import pymongo
import certifi

# ▪ Task 1: load the original data 
df = pd.read_csv("flights.csv")

# ▪ Task 2: create a new collection called flights inside 
# the ISA414 database
client = pymongo.MongoClient("mongodb://igeljj:abcd1234@ac-nxgq7yt-shard-00-00.7xcrv0l.mongodb.net:27017,ac-nxgq7yt-shard-00-01.7xcrv0l.mongodb.net:27017,ac-nxgq7yt-shard-00-02.7xcrv0l.mongodb.net:27017/?ssl=true&replicaSet=atlas-5k6q81-shard-0&authSource=admin&retryWrites=true&w=majority", tlsCAFile=certifi.where())
db = client.ISA414
collection = db.flights


# Task 3: populate the flights collection
data_json = df.to_dict("records")
collection.insert_many(data_json)

# %% [markdown]
# # Queries

# %%
# 1. Add the new key-value pair "delayed":"true" to the documents containing 
# delayed flights  (dep_delay > 0)

result = collection.find({"dep_delay":{"$gt":0}})


query = {"dep_delay":{"$gt":0}}


new_values = {"$set":{"delayed":True}}


collection.update_many(query, new_values)

# %%
# 2. Check that the update statement worked by writing a query that returns 
# all the data about delayed flights (i.e., delayed:true )
result = collection.find({"dep_delay":{"$gt":0}})
for result in collection.find():
  print(result)
# Out:
# {'_id': ObjectId('6335bc68cb801ab87bd8f7e0'), 'year': 2013, 'month': 1, 'day': 1, 'dep_time': 558.0, 'sched_dep_time': 600, 'dep_delay': -2.0, 'arr_time': 924.0, 'sched_arr_time': 917, 'arr_delay': 7.0, 'carrier': 'UA', 'flight': 194, 'tailnum': 'N29129', 'origin': 'JFK', 'dest': 'LAX', 'air_time': 345.0, 'distance': 2475, 'hour': 6, 'minute': 0, 'time_hour': '2013-01-01 06:00:00'}
# {'_id': ObjectId('6335bc68cb801ab87bd8f81d'), 'year': 2013, 'month': 1, 'day': 1, 'dep_time': 715.0, 'sched_dep_time': 713, 'dep_delay': 2.0, 'arr_time': 911.0, 'sched_arr_time': 850, 'arr_delay': 21.0, 'carrier': 'UA', 'flight': 544, 'tailnum': 'N841UA', 'origin': 'EWR', 'dest': 'ORD', 'air_time': 156.0, 'distance': 719, 'hour': 7, 'minute': 13, 'time_hour': '2013-01-01 07:00:00', 'delayed': True}
# ...

# %%
# 3. Return only the carrier names for the delayed flights (i.e., delayed:true )

result = collection.find({"dep_delay":{"$gt":0}})
for result in collection.find():
  print(result['carrier'])
# Out:
# UA
# UA
# B6
# DL
# UA
# B6
# AA
# AA
# DL
# AS
# B6
# AA
# DL
# UA
# WN
# UA
# B6
# DL
# B6
# WN
# B6
# DL
# UA
# B6
# EV
# UA
# UA
# EV
# EV
# EV
# WN
# UA
# UA
# EV
# UA
# US
# UA
# VX
# UA
# DL
# EV
# B6
# B6
# MQ
# DL
# DL
# DL
# UA
# UA
# AA
# EV
# B6
# B6
# MQ
# UA
# MQ
# AA
# UA
# EV
# EV
# EV
# B6
# B6
# B6
# UA
# B6
# UA
# DL
# UA
# UA
# UA
# DL
# DL
# UA
# VX
# B6
# EV
# AA
# UA
# EV
# US
# AA
# MQ
# AA
# AA
# WN
# MQ
# AA
# B6
# B6
# UA
# US
# MQ
# B6
# UA
# UA
# B6
# MQ
# DL
# MQ
# DL
# EV
# DL
# AA
# MQ
# UA
# MQ
# B6
# DL
# MQ
# AA
# AA
# B6
# B6
# MQ
# EV
# AA
# EV
# UA
# DL
# B6
# EV
# B6
# DL
# MQ
# DL
# B6
# MQ
# MQ
# UA
# EV
# B6
# EV
# AA
# DL
# B6
# MQ
# B6
# MQ
# WN
# B6
# UA
# MQ
# B6
# US
# UA
# AA
# UA
# WN
# B6
# DL
# FL
# DL
# B6
# UA
# DL
# DL
# AA
# US
# UA
# EV
# UA
# EV
# DL
# B6
# WN
# UA
# DL
# B6
# B6
# UA
# MQ
# DL
# EV
# UA
# AA
# VX
# MQ
# B6
# B6
# DL
# UA
# FL
# B6
# US
# DL
# B6
# MQ
# EV
# UA
# DL
# UA
# B6
# US
# B6
# AA
# DL
# UA
# B6
# EV
# ...
